# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#loading dataset
df=pd.read_csv("C:/Users/LENOVO/salary_satisfaction.csv", encoding="ISO-8859-1")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df.head()
# Out:
#          id  Target_Salary  Target_Satisfied     LOAN_AMT  \
# 0  68407277       42405.00                 0   $3,600.00
# 1  68355089       60740.00                 1  $24,700.00
# 2  68341763       51907.68                 0  $20,000.00
# 3  66310712       51907.68                 0  $35,000.00
# 4  68476807          35.00                 1  $10,400.00
#
#                                       Business Title  \
# 0                                    Account Manager
# 1           EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT
# 2  Maintenance Worker - Technical Services-Heatin...
# 3  Maintenance Worker - Technical Services-Heatin...
# 4                                  Temporary Painter
#
#               Civil Service Title              Division/Work Unit  \
# 0  CONTRACT REVIEWER (OFFICE OF L            Strategy & Analytics
# 1  ADMINISTRATIVE BUSINESS PROMOT            Tech Talent Pipeline
# 2              MAINTENANCE WORKER  Management Services Department
# ...

# %%
#del dummdata --->whever you want empty dataset
df.head()
# Out:
#          id  Target_Salary  Target_Satisfied     LOAN_AMT  \
# 0  68407277       42405.00                 0   $3,600.00
# 1  68355089       60740.00                 1  $24,700.00
# 2  68341763       51907.68                 0  $20,000.00
# 3  66310712       51907.68                 0  $35,000.00
# 4  68476807          35.00                 1  $10,400.00
#
#                                       Business Title  \
# 0                                    Account Manager
# 1           EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT
# 2  Maintenance Worker - Technical Services-Heatin...
# 3  Maintenance Worker - Technical Services-Heatin...
# 4                                  Temporary Painter
#
#               Civil Service Title              Division/Work Unit  \
# 0  CONTRACT REVIEWER (OFFICE OF L            Strategy & Analytics
# 1  ADMINISTRATIVE BUSINESS PROMOT            Tech Talent Pipeline
# 2              MAINTENANCE WORKER  Management Services Department
# ...

# %%
df.columns=['id', 'Target_Salary', 'Target_Satisfied', 'LOAN_AMT', 'BTitle',
       'CTitle', 'Division', 'JD',
       'QualReq', 'Skills',
       'AddInfo', 'Apply', 'Shift',
       'ResiRqmnt', 'PDate', 'PUpdated',
       'PDate1', 'FormalEducation', 'UndergradMajor', 'CompanySize',
       'DevType', 'YrsCd', 'YrsCdPrf', 'HopeFiveYears',
       'JobStatus', 'LastJob', 'UpdateCV', 'CTools',
       'TProductive', 'EduTypes', 'SelfTTypes',
       'TimeAfterBootcamp', 'HackathonReasons', 'AD1',
       'AD2', 'AD3', 'LangWorked',
       'LangNxtYr', 'DbWorked',
       'DbNxtYr', 'PlatformWorked',
       'PlatformNxtYr', 'FrameworkWorked',
       'FrameworkNxtYr', 'IDE', 'OS', 'Methodology',
       'VerC', 'CInCode', 'AIDangerous', 'AIInterest',
       'AIRespons', 'AIFuture', 'Age', 'term', 'loan_status', 'pymnt_plan',
       'orignal_web_dir', 'purpose', 'title', 'zip_code',
       'addr_state', 'dti', 'earliest_cr_line', 'last_pymnt_d',
       'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d', 'Time',
       'emp_length', 'your_favart_tdy', 'url', 'Email',
       'haddress', 'lat', 'long', 'PHONE', 'oaddress',
       'website', 'dateAdded', 'paddress', 'phones', 'CrimeTime']

# %%
# clean and convert LOAN_AMT,term,Age to int type 
data=df.copy()
data['LOAN_AMT'] = data['LOAN_AMT'].str.replace('$', '')
data['LOAN_AMT'] = data['LOAN_AMT'].str.replace(',', '')
data['LOAN_AMT'] = pd.to_numeric(data.LOAN_AMT, errors='coerce')
data['term']=data['term'].str.replace('months','')
data['term'] = pd.to_numeric(data.term, errors='coerce')

#data['zip_code']=data['zip_code'].str.replace('xx','')
#data['zip_code'] = pd.to_numeric(data.zip_code, errors='coerce')
data.head()
# Out:
#          id  Target_Salary  Target_Satisfied  LOAN_AMT  \
# 0  68407277       42405.00                 0    3600.0
# 1  68355089       60740.00                 1   24700.0
# 2  68341763       51907.68                 0   20000.0
# 3  66310712       51907.68                 0   35000.0
# 4  68476807          35.00                 1   10400.0
#
#                                               BTitle  \
# 0                                    Account Manager
# 1           EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT
# 2  Maintenance Worker - Technical Services-Heatin...
# 3  Maintenance Worker - Technical Services-Heatin...
# 4                                  Temporary Painter
#
#                            CTitle                        Division  \
# 0  CONTRACT REVIEWER (OFFICE OF L            Strategy & Analytics
# 1  ADMINISTRATIVE BUSINESS PROMOT            Tech Talent Pipeline
# 2              MAINTENANCE WORKER  Management Services Department
# ...

# %%
dummdata=data.copy()

 #LanguageWorkedWith
#for col in categorical_fix:

# Let's say we have a column 'b' which has more than 500 categories.
# Find the top 10 most frequent categories for column 'b'
res=dummdata.LangWorked.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.LangWorked.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    LangWorked_nw = np.where(dummdata['LangWorked'] == cat, 1, 0) 
    #print(dummdata['LanguageWorked'])
# Out:
# Top 20 Categories : ====>>> C#;JavaScript;SQL;HTML;CSS                       55
# JavaScript;PHP;SQL;HTML;CSS                      42
# C#;JavaScript;SQL;TypeScript;HTML;CSS            35
# Java                                             31
# JavaScript;HTML;CSS                              28
# JavaScript;PHP;HTML;CSS                          26
# JavaScript;PHP;SQL;HTML;CSS;Bash/Shell           19
# C#;JavaScript;TypeScript;HTML;CSS                18
# Java;JavaScript;SQL;HTML;CSS                     18
# JavaScript;TypeScript;HTML;CSS                   17
# C#;SQL                                           15
# C#                                               15
# C#;JavaScript;HTML;CSS                           13
# Java;SQL                                         13
# C#;JavaScript;PHP;SQL;HTML;CSS                   13
# PHP                                              11
# JavaScript;PHP;Python;SQL;HTML;CSS;Bash/Shell    11
# JavaScript;Python;SQL;HTML;CSS;Bash/Shell        10
# ...

# %%
dummdata=dummdata.assign(LangWorked_nw=LangWorked_nw)

# %%
#LanguageNxtYr
res=dummdata.LangNxtYr.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.LangNxtYr.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    LangNxtYr_nw = np.where(dummdata['LangNxtYr'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> C#                                       28
# Python                                   28
# C#;JavaScript;SQL;TypeScript;HTML;CSS    22
# Java                                     20
# C#;JavaScript;SQL;HTML;CSS               19
# TypeScript                               16
# JavaScript;HTML;CSS                      16
# Swift                                    15
# JavaScript;TypeScript;HTML;CSS           15
# C++;Python                               13
# Kotlin                                   12
# Go                                       12
# JavaScript                               10
# Java;Kotlin                              10
# Python;R                                  9
# C#;SQL                                    9
# JavaScript;PHP;SQL;HTML;CSS               9
# JavaScript;Python                         9
# C#;JavaScript;HTML;CSS                    9
# JavaScript;PHP;HTML;CSS                   9
# Name: LangNxtYr, dtype: int64
# ...

# %%
dummdata=dummdata.assign(LangNxtYr_nw=LangNxtYr_nw)

# %%
#DbWorked 
res=dummdata.DbWorked.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.DbWorked.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    DbWorked_nw = np.where(dummdata['DbWorked'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> SQL Server                                                 196
# MySQL                                                      155
# SQL Server;MySQL                                            91
# PostgreSQL                                                  77
# SQLite                                                      45
# MySQL;PostgreSQL                                            44
# MongoDB;MySQL                                               39
# MySQL;SQLite                                                35
# MySQL;MariaDB                                               31
# MongoDB                                                     31
# SQL Server;Microsoft Azure (Tables, CosmosDB, SQL, etc)     27
# SQL Server;PostgreSQL                                       23
# MongoDB;SQL Server;MySQL                                    23
# SQL Server;Oracle                                           22
# ...

# %%
dummdata=dummdata.assign(DbWorked_nw=DbWorked_nw)

# %%
# DbNxtYr

res=dummdata.DbNxtYr.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.DbNxtYr.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    DbNxtYr_nw = np.where(dummdata['DbNxtYr'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> SQL Server                                                 89
# PostgreSQL                                                 78
# MongoDB                                                    74
# MySQL                                                      60
# SQL Server;Microsoft Azure (Tables, CosmosDB, SQL, etc)    31
# SQL Server;MySQL                                           29
# SQLite                                                     28
# MongoDB;MySQL                                              27
# MongoDB;Elasticsearch                                      21
# MySQL;MariaDB                                              21
# Redis                                                      17
# MongoDB;Redis                                              16
# MySQL;SQLite                                               15
# Microsoft Azure (Tables, CosmosDB, SQL, etc)               15
# Cassandra                                                  15
# ...

# %%
dummdata=dummdata.assign(DbNxtYr_nw=DbNxtYr_nw)

# %%
# PlatformWorked
res=dummdata.PlatformWorked.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.PlatformWorked.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    PlatformWorked_nw = np.where(dummdata['PlatformWorked'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> Windows Desktop or Server                       164
# Linux                                           141
# Linux;Windows Desktop or Server                  84
# AWS                                              62
# Android                                          53
# WordPress                                        41
# AWS;Linux                                        37
# Linux;Mac OS                                     35
# Azure                                            30
# Android;Firebase                                 26
# Azure;Windows Desktop or Server                  26
# iOS                                              24
# Android;Windows Desktop or Server                19
# Android;iOS                                      18
# Android;Linux                                    18
# AWS;Linux;Mac OS                                 17
# Linux;Raspberry Pi;Windows Desktop or Server     16
# AWS;Linux;Windows Desktop or Server              16
# ...

# %%
dummdata=dummdata.assign(PlatformWorked_nw=PlatformWorked_nw)

# %%
#PlatformNxtYr
res=dummdata.PlatformNxtYr.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.PlatformNxtYr.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    PlatformNxtYr_nw = np.where(dummdata['PlatformNxtYr'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> Linux                                   109
# Windows Desktop or Server                56
# Linux;Windows Desktop or Server          50
# AWS                                      45
# Android                                  45
# AWS;Linux                                43
# Firebase                                 30
# Azure;Windows Desktop or Server          23
# Azure                                    23
# Linux;Raspberry Pi                       21
# Android;iOS                              18
# Linux;Mac OS                             17
# Android;Linux                            17
# iOS                                      16
# Raspberry Pi                             13
# Android;iOS;Firebase                     12
# WordPress                                12
# Mac OS                                   11
# AWS;Google Cloud Platform/App Engine     11
# Android;Firebase                         11
# Name: PlatformNxtYr, dtype: int64
# ...

# %%
dummdata=dummdata.assign(PlatformNxtYr_nw=PlatformNxtYr_nw)

# %%
#FrameworkWorked 
res=dummdata.FrameworkWorked.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.FrameworkWorked.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    FrameworkWorked_nw = np.where(dummdata['FrameworkWorked'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> .NET Core                    143
# Spring                       113
# Node.js                      110
# Node.js;React                 99
# Angular                       93
# Angular;Node.js               92
# React                         61
# Django                        52
# Angular;Node.js;React         48
# Angular;.NET Core             47
# Angular;.NET Core;Node.js     39
# Angular;Spring                35
# .NET Core;Node.js             32
# Angular;Node.js;Spring        30
# TensorFlow                    29
# Angular;Node.js;Cordova       26
# .NET Core;Xamarin             25
# .NET Core;Node.js;React       22
# Angular;React                 19
# Node.js;Spring                19
# Name: FrameworkWorked, dtype: int64
# ...

# %%
dummdata=dummdata.assign(FrameworkWorked_nw=FrameworkWorked_nw)

# %%
#FrameworkNxtYr
res=dummdata.FrameworkNxtYr.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.FrameworkNxtYr.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    FrameworkNxtYr_nw = np.where(dummdata['FrameworkNxtYr'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> Node.js;React                              113
# .NET Core                                   97
# Node.js                                     80
# TensorFlow                                  70
# React                                       68
# Angular;Node.js;React                       63
# Angular;Node.js                             49
# Spring                                      44
# Django                                      41
# Angular                                     35
# Angular;.NET Core;Node.js                   32
# .NET Core;Node.js                           29
# Angular;.NET Core                           28
# Node.js;React;TensorFlow                    25
# Angular;.NET Core;Node.js;React             23
# .NET Core;Xamarin                           23
# Angular;React                               22
# React;TensorFlow                            21
# Angular;.NET Core;Node.js;React;Xamarin     20
# ...

# %%
dummdata=dummdata.assign(FrameworkNxtYr_nw=FrameworkNxtYr_nw)

# %%
#IDE 
res=dummdata.IDE.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.IDE.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    IDE_nw = np.where(dummdata['IDE'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> Visual Studio;Visual Studio Code                           83
# Notepad++;Visual Studio;Visual Studio Code                 82
# Notepad++;Visual Studio                                    75
# Visual Studio                                              66
# Visual Studio Code                                         64
# Vim                                                        60
# Sublime Text                                               46
# Atom                                                       31
# Sublime Text;Visual Studio Code                            28
# Vim;Visual Studio Code                                     25
# IntelliJ;Vim                                               25
# IntelliJ                                                   24
# Sublime Text;Vim                                           22
# IntelliJ;Sublime Text                                      20
# Xcode                                                      19
# ...

# %%
dummdata=dummdata.assign(IDE_nw=IDE_nw)

# %%
#earliest_cr_line

res=dummdata.earliest_cr_line.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.IDE.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    earliest_cr_line_nw = np.where(dummdata['earliest_cr_line'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> 3-Aug     29
# 4-Sep     27
# 3-Sep     27
# Nov-99    27
# 2-Sep     27
# 3-Jul     25
# 4-Oct     25
# 4-Nov     23
# 3-Mar     22
# Nov-00    22
# Nov-94    21
# 2-Aug     21
# Oct-99    21
# 4-Aug     21
# 3-Nov     20
# 1-May     20
# 2-Oct     20
# 1-Oct     20
# 3-Oct     19
# 1-Jul     19
# Name: earliest_cr_line, dtype: int64
# top 10 Categories=================> ['Visual Studio;Visual Studio Code', 'Notepad++;Visual Studio;Visual Studio Code', 'Notepad++;Visual Studio', 'Visual Studio', 'Visual Studio Code', 'Vim', 'Sublime Text', 'Atom', 'Sublime Text;Visual Studio Code', 'Vim;Visual Studio Code', 'IntelliJ;Vim', 'IntelliJ', 'Sublime Text;Vim', 'IntelliJ;Sublime Text', 'Xcode', 'Eclipse;Notepad++', 'Notepad++;Sublime Text;Visual Studio;Visual Studio Code', 'Sublime Text;Visual Studio', 'Sublime Text;Visual Studio;Visual Studio Code', 'PHPStorm']

# %%
dummdata=dummdata.assign(earliest_cr_line_nw=earliest_cr_line_nw)

# %%
#officeaddress
res=dummdata.oaddress.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.oaddress.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    oaddress_nw = np.where(dummdata['oaddress'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> 445 St. Paul St., Rochester, New York, 14605               3
# 1004 S. Olde Oneida St., Appleton, Wisconsin, 54915        3
# 147 E. Main St., Newark, Delaware, 19711                   2
# 2005 Lincoln Ave., Ogden, Utah, 84401                      2
# 1735 19th St. Suite 100, Denver, Colorado, 80202           2
# 149 Steele St., Denver, Colorado, 80206                    2
# 250 Main St., Park City, Utah, 84060                       2
# 577 Main St., Hudson, Massachusetts, 1749                  2
# 9710 SE Washington St. Suite A, Portland, Oregon, 97216    2
# 4 South Cascade Ave., Colorado Springs, Colorado, 80903    2
# 513 N. Ward Blvd., Wilson, North Carolina, 27893           2
# 12492 Prospect Road, Strongsville, Ohio, 44136             2
# 1711 W. Hwy. 50, O'Fallon, Illinois, 62269                 2
# 4246 North Buffalo Rd., Orchard Park, New York, 14127      2
# 240 N Broadway, Ste 2, Portland, Oregon, 97227             2
# ...

# %%
dummdata=dummdata.assign(oaddress_nw=oaddress_nw)

# %%
#next is convert 12 columns 
#FormalEducation 
res=dummdata.FormalEducation.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.FormalEducation.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    FormalEducation_nw = np.where(dummdata['FormalEducation'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> Bachelors degree (BA, BS, B.Eng., etc.)                                              1442
# Masters degree (MA, MS, M.Eng., MBA, etc.)                                            716
# Some college/university study without earning a degree                                 319
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     179
# Associate degree                                                                        92
# Other doctoral degree (Ph.D, Ed.D., etc.)                                               75
# Professional degree (JD, MD, etc.)                                                      43
# Primary/elementary school                                                               17
# I never completed any formal education                                                  11
# Name: FormalEducation, dtype: int64
# ...

# %%
dummdata=dummdata.assign(FormalEducation_nw=FormalEducation_nw)

# %%
#UndergradMajor
res=dummdata.UndergradMajor.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.UndergradMajor.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    UndergradMajor_nw = np.where(dummdata['UndergradMajor'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> Computer science, computer engineering, or software engineering          1698
# Information systems, information technology, or system administration     247
# Another engineering discipline (ex. civil, electrical, mechanical)        205
# A natural science (ex. biology, chemistry, physics)                       109
# Mathematics or statistics                                                  86
# A business discipline (ex. accounting, finance, marketing)                 65
# Web development or web design                                              64
# A humanities discipline (ex. literature, history, philosophy)              48
# Fine arts or performing arts (ex. graphic design, music, studio art)       38
# A social science (ex. anthropology, psychology, political science)         38
# I never declared a major                                                   23
# A health science (ex. nursing, pharmacy, radiology)                         3
# ...

# %%
dummdata=dummdata.assign(UndergradMajor_nw=UndergradMajor_nw)

# %%
#CompanySize 

res=dummdata.CompanySize.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.CompanySize.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    CompanySize_nw = np.where(dummdata['CompanySize'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> 20 to 99 employees          719
# 100 to 499 employees        580
# 10,000 or more employees    387
# 10 to 19 employees          329
# 1,000 to 4,999 employees    316
# Fewer than 10 employees     304
# 500 to 999 employees        205
# 5,000 to 9,999 employees    106
# Name: CompanySize, dtype: int64
# top 10 Categories=================> ['20 to 99 employees', '100 to 499 employees', '10,000 or more employees', '10 to 19 employees', '1,000 to 4,999 employees', 'Fewer than 10 employees', '500 to 999 employees', '5,000 to 9,999 employees']

# %%
dummdata=dummdata.assign(CompanySize_nw=CompanySize_nw)

# %%
#YrsCd 
res=dummdata.YrsCd.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.YrsCd.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    YrsCd_nw = np.where(dummdata['YrsCd'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> 3-5 years           699
# 6-8 years           630
# 9-11 years          443
# 12-14 years         277
# 0-2 years           248
# 15-17 years         205
# 18-20 years         179
# 30 or more years     93
# 21-23 years          82
# 24-26 years          54
# 27-29 years          33
# Name: YrsCd, dtype: int64
# top 10 Categories=================> ['3-5 years', '6-8 years', '9-11 years', '12-14 years', '0-2 years', '15-17 years', '18-20 years', '30 or more years', '21-23 years', '24-26 years', '27-29 years']

# %%
dummdata=dummdata.assign(YrsCd_nw=YrsCd_nw)

# %%
#YearsCodingProf
res=dummdata.YrsCdPrf.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.YrsCdPrf.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    YrsCdPrf_nw = np.where(dummdata['YrsCdPrf'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> 3-5 years           791
# 0-2 years           653
# 6-8 years           401
# 9-11 years          249
# 12-14 years         139
# 15-17 years         103
# 18-20 years          89
# 21-23 years          42
# 30 or more years     38
# 24-26 years          23
# 27-29 years          10
# Name: YrsCdPrf, dtype: int64
# top 10 Categories=================> ['3-5 years', '0-2 years', '6-8 years', '9-11 years', '12-14 years', '15-17 years', '18-20 years', '21-23 years', '30 or more years', '24-26 years', '27-29 years']

# %%
dummdata=dummdata.assign(YrsCdPrf_nw=YrsCdPrf_nw)

# %%
#AIInterest

res=dummdata.AIInterest.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.AIInterest.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    AIInterest_nw = np.where(dummdata['AIInterest'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> Increasing automation of jobs                                                871
# Artificial intelligence surpassing human intelligence ("the singularity")    478
# Algorithms making important decisions                                        469
# Evolving definitions of "fairness" in algorithmic versus human decisions     258
# Name: AIInterest, dtype: int64
# top 10 Categories=================> ['Increasing automation of jobs', 'Artificial intelligence surpassing human intelligence ("the singularity")', 'Algorithms making important decisions', 'Evolving definitions of "fairness" in algorithmic versus human decisions']

# %%
dummdata=dummdata.assign(AIInterest_nw=AIInterest_nw)

# %%
#AIResponsible 

res=dummdata.AIRespons.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.AIRespons.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    AIRespons_nw = np.where(dummdata['AIRespons'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> The developers or the people creating the AI    992
# A governmental or other regulatory body         597
# Prominent industry leaders                      316
# Nobody                                          165
# Name: AIRespons, dtype: int64
# top 10 Categories=================> ['The developers or the people creating the AI', 'A governmental or other regulatory body', 'Prominent industry leaders', 'Nobody']

# %%
dummdata=dummdata.assign(AIRespons_nw=AIRespons_nw)

# %%
#AIFuture

res=dummdata.AIFuture.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.AIFuture.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    AIFuture_nw = np.where(dummdata['AIFuture'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> I'm excited about the possibilities more than worried about the dangers.        1601
# I'm worried about the dangers more than I'm excited about the possibilities.     402
# I don't care about it, or I haven't thought about it.                            193
# Name: AIFuture, dtype: int64
# top 10 Categories=================> ["I'm excited about the possibilities more than worried about the dangers.", "I'm worried about the dangers more than I'm excited about the possibilities.", "I don't care about it, or I haven't thought about it."]

# %%
dummdata=dummdata.assign(AIFuture_nw=AIFuture_nw)

# %%
#Age

res=dummdata.Age.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.Age.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    Age_nw = np.where(dummdata['Age'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> 25 - 34 years old     1117
# 18 - 24 years old      421
# 35 - 44 years old      364
# 45 - 54 years old       93
# 55 - 64 years old       23
# Under 18 years old       9
# Name: Age, dtype: int64
# top 10 Categories=================> ['25 - 34 years old', '18 - 24 years old', '35 - 44 years old', '45 - 54 years old', '55 - 64 years old', 'Under 18 years old']

# %%
dummdata=dummdata.assign(Age_nw=Age_nw)

# %%
#loan_status 

res=dummdata.loan_status.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.loan_status.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    loan_status_nw = np.where(dummdata['loan_status'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> Fully Paid            2154
# Charged Off            456
# Current                319
# Late (31-120 days)      14
# In Grace Period          2
# Late (16-30 days)        1
# Name: loan_status, dtype: int64
# top 10 Categories=================> ['Fully Paid', 'Charged Off', 'Current', 'Late (31-120 days)', 'In Grace Period', 'Late (16-30 days)']

# %%
dummdata=dummdata.assign(loan_status_nw=loan_status_nw)

# %%
#addr_state 
res=dummdata.addr_state.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.addr_state.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    addr_state_nw = np.where(dummdata['addr_state'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> CA    357
# TX    247
# NY    238
# FL    197
# OH    106
# IL    106
# VA    103
# GA    100
# MD     99
# NJ     96
# PA     95
# MA     87
# MI     83
# NC     82
# CO     67
# AZ     62
# MO     60
# WA     60
# MN     57
# TN     51
# Name: addr_state, dtype: int64
# top 10 Categories=================> ['CA', 'TX', 'NY', 'FL', 'OH', 'IL', 'VA', 'GA', 'MD', 'NJ', 'PA', 'MA', 'MI', 'NC', 'CO', 'AZ', 'MO', 'WA', 'MN', 'TN']

# %%
dummdata=dummdata.assign(addr_state_nw=addr_state_nw)

# %%
#emp_length
res=dummdata.emp_length.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.emp_length.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    emp_length_nw = np.where(dummdata['emp_length'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> 10+ years    322
# 6 years       50
# 3 years       50
# < 1 year      49
# 8 years       49
# 5 years       48
# 2 years       48
# 1 year        25
# 7 years       25
# 4 years       25
# 9 years       24
# Name: emp_length, dtype: int64
# top 10 Categories=================> ['10+ years', '6 years', '3 years', '< 1 year', '8 years', '5 years', '2 years', '1 year', '7 years', '4 years', '9 years']

# %%
dummdata=dummdata.assign(emp_length_nw=emp_length_nw)

# %%
#Checking corelation with dropped data

# %%
#QualReq
res=dummdata.QualReq.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.QualReq.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    QualReq_nw = np.where(dummdata['QualReq'] == cat, 1, 0) #
# Out:
# Top 20 Categories : ====>>> 1. A baccalaureate degree from an accredited college and two years of experience in community work or community centered activities in an area related to the duties described above; or  2. High school graduation or equivalent and six years of experience in community work or community centered activities in an area related to the duties as described above; or  3. Education and/or experience which is equivalent to "1" or "2" above. However, all candidates must have at least one year of experience as described in "1" above.                                                                                                                                                                                                                                                                                                                                                                                                                                                            
# ...

# %%
dummdata=dummdata.assign(QualReq_nw=QualReq_nw)

# %%
res=dummdata.AddInfo.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.AddInfo.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    AddInfo_nw = np.where(dummdata['AddInfo'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> Appointments are subject to OMB approval. For additional information about DEP, visit www.nyc.gov/dep  DEP is an equal opportunity employer with a strong commitment to the diversity of our organization and workforce. Your voluntary response to the NYCAPS on-line application section for referral information will assist us tremendously in our ability to track the success of our outreach and recruitment efforts. Please be sure to indicate your source of referral to this job.  NOTE: This position is open to qualified persons with a disability who are eligible for the 55-a Program and also meet the education and experience requirements as listed in the job posting notice. Please indicate on your resume or cover letter that you would like to be considered for the position under the 55-a Program. This position is also open to non 55-a Program candidates who meet the education and experience requirements as listed in the job posting notice.                        
# ...

# %%
dummdata=dummdata.assign(AddInfo_nw=AddInfo_nw)

# %%
res=dummdata.Apply.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.Apply.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    Apply_nw = np.where(dummdata['Apply'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> Click the "Apply Now" button.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             
# ...

# %%
dummdata=dummdata.assign(Apply_nw=Apply_nw)

# %%
dummdata['PDate'] = dummdata['PDate'].str.replace('00:00:00.000', '')

res=dummdata.PDate.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.PDate.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    PDate_nw = np.where(dummdata['PDate'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> 2019-11-01T    64
# 2019-09-30T    60
# 2019-11-26T    58
# 2019-11-27T    55
# 2019-12-10T    53
# 2019-12-13T    52
# 2019-12-06T    52
# 2019-12-11T    48
# 2019-10-28T    45
# 2019-11-22T    40
# 2019-10-31T    38
# 2019-12-03T    37
# 2019-11-20T    33
# 2019-11-21T    33
# 2019-11-29T    32
# 2019-12-04T    31
# 2019-12-16T    31
# 2019-11-04T    31
# 2019-12-09T    29
# 2019-07-26T    29
# Name: PDate, dtype: int64
# top 10 Categories=================> ['2019-11-01T', '2019-09-30T', '2019-11-26T', '2019-11-27T', '2019-12-10T', '2019-12-13T', '2019-12-06T', '2019-12-11T', '2019-10-28T', '2019-11-22T', '2019-10-31T', '2019-12-03T', '2019-11-20T', '2019-11-21T', '2019-11-29T', '2019-12-04T', '2019-12-16T', '2019-11-04T', '2019-12-09T', '2019-07-26T']

# %%
dummdata=dummdata.assign(PDate_nw=PDate_nw)

# %%
res=dummdata.PUpdated.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.PUpdated.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    PUpdated_nw = np.where(dummdata['PUpdated'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> 2019-12-13T00:00:00.000    82
# 2019-12-16T00:00:00.000    72
# 2019-12-11T00:00:00.000    68
# 2019-11-27T00:00:00.000    67
# 2019-12-10T00:00:00.000    66
# 2019-11-26T00:00:00.000    66
# 2019-12-12T00:00:00.000    62
# 2019-12-05T00:00:00.000    56
# 2019-12-06T00:00:00.000    47
# 2019-11-04T00:00:00.000    45
# 2019-11-25T00:00:00.000    42
# 2019-12-03T00:00:00.000    38
# 2019-10-28T00:00:00.000    38
# 2019-11-22T00:00:00.000    38
# 2019-12-09T00:00:00.000    37
# 2019-11-29T00:00:00.000    36
# 2019-11-01T00:00:00.000    36
# 2019-11-21T00:00:00.000    36
# 2019-12-02T00:00:00.000    34
# 2019-10-02T00:00:00.000    33
# Name: PUpdated, dtype: int64
# ...

# %%
dummdata=dummdata.assign(PUpdated_nw=PUpdated_nw)

# %%
res=dummdata.PDate1.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.PDate1.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    PDate1_nw = np.where(dummdata['PDate1'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> 2019-12-17T00:00:00.000    2942
# Name: PDate1, dtype: int64
# top 10 Categories=================> ['2019-12-17T00:00:00.000']

# %%
dummdata=dummdata.assign( PDate1_nw= PDate1_nw)

# %%
res=dummdata.PDate1.value_counts().sort_values(ascending = False).head(20)
print("Top 20 Categories :",'====>>>',res)
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in dummdata.PDate1.value_counts().sort_values(ascending = False).head(20).index]
print("top 10 Categories=================>", top_10_occurring_cat)
# preparing binary variable for those top 10 
for cat in top_10_occurring_cat:
    PDate1_nw = np.where(dummdata['PDate1'] == cat, 1, 0)
# Out:
# Top 20 Categories : ====>>> 2019-12-17T00:00:00.000    2942
# Name: PDate1, dtype: int64
# top 10 Categories=================> ['2019-12-17T00:00:00.000']

# %%
dummdata=dummdata.assign(PDate1_nw=PDate1_nw)

# %%
dummdata['LangWorked_nw']= pd.to_numeric(dummdata.LangWorked_nw, errors='coerce')
dummdata['LangNxtYr_nw']= pd.to_numeric(dummdata.LangNxtYr_nw, errors='coerce')
dummdata['DbWorked_nw']= pd.to_numeric(dummdata.DbWorked_nw, errors='coerce')
dummdata['DbNxtYr_nw']= pd.to_numeric(dummdata.DbNxtYr_nw, errors='coerce')
dummdata['PlatformWorked_nw']= pd.to_numeric(dummdata.PlatformWorked_nw, errors='coerce')
dummdata['PlatformNxtYr_nw']= pd.to_numeric(dummdata.PlatformNxtYr_nw, errors='coerce')
dummdata['FrameworkWorked_nw']= pd.to_numeric(dummdata.FrameworkWorked_nw, errors='coerce')
dummdata['FrameworkNxtYr_nw']= pd.to_numeric(dummdata.FrameworkNxtYr_nw, errors='coerce')
dummdata['IDE_nw']= pd.to_numeric(dummdata.IDE_nw, errors='coerce')
dummdata['earliest_cr_line_nw']= pd.to_datetime(dummdata.earliest_cr_line_nw, errors='coerce')
dummdata['oaddress_nw']= pd.to_numeric(dummdata.oaddress_nw, errors='coerce')
dummdata['CompanySize_nw'] = pd.to_numeric(dummdata.CompanySize_nw, errors='coerce')
dummdata['YrsCd_nw']= pd.to_numeric(dummdata.YrsCd_nw, errors='coerce')
dummdata['YrsCdPrf_nw']= pd.to_numeric(dummdata.YrsCdPrf_nw, errors='coerce')
dummdata['AIInterest_nw']=pd.to_numeric(dummdata.AIInterest_nw, errors='coerce')
dummdata['AIRespons_nw']=pd.to_numeric(dummdata.AIRespons_nw, errors='coerce')
dummdata['AIFuture_nw']=pd.to_numeric(dummdata.AIFuture_nw, errors='coerce')
dummdata['Age_nw']=pd.to_numeric(dummdata.Age_nw, errors='coerce')
dummdata['loan_status_nw']=pd.to_numeric(dummdata.loan_status_nw, errors='coerce')
dummdata['addr_state_nw']=pd.to_numeric(dummdata.addr_state_nw, errors='coerce')
dummdata['emp_length_nw']=pd.to_numeric(dummdata.emp_length_nw, errors='coerce')
dummdata['QualReq_nw']=pd.to_numeric(dummdata.QualReq_nw,errors='coerce')
dummdata['AddInfo_nw']=pd.to_numeric(dummdata.AddInfo_nw,errors='coerce')
dummdata['PDate_nw']=pd.to_numeric(dummdata.PDate_nw,errors='coerce')
dummdata['PUpdated_nw']=pd.to_numeric(dummdata.PUpdated_nw,errors='coerce')
dummdata['PDate1_nw']=pd.to_numeric(dummdata.PDate1_nw,errors='coerce')

# %%
final=dummdata.corrwith(dummdata["Target_Salary"])
print(final)
# Out:
# id                   -0.010424
# Target_Salary         1.000000
# Target_Satisfied      0.007766
# LOAN_AMT             -0.005426
# term                 -0.003239
# dti                   0.002491
# last_pymnt_amnt       0.009170
# lat                   0.014446
# long                 -0.013123
# LangWorked_nw        -0.003209
# LangNxtYr_nw         -0.016367
# DbWorked_nw          -0.006431
# DbNxtYr_nw            0.002249
# PlatformWorked_nw     0.001042
# PlatformNxtYr_nw     -0.015697
# FrameworkWorked_nw    0.028617
# FrameworkNxtYr_nw     0.033925
# IDE_nw               -0.001656
# oaddress_nw          -0.004227
# FormalEducation_nw   -0.014156
# UndergradMajor_nw    -0.001995
# CompanySize_nw       -0.003267
# YrsCd_nw              0.017420
# YrsCdPrf_nw           0.027569
# AIInterest_nw        -0.022711
# AIRespons_nw          0.011563
# AIFuture_nw          -0.005032
# Age_nw               -0.029098
# loan_status_nw       -0.040214
# addr_state_nw         0.008111
# ...

# %%
corr = dummdata.corr()
fig, ax = plt.subplots(figsize=(20,15)) 
sns.heatmap(corr, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
#preparing data for training
X = corr.iloc[:, 0:36].values
y = corr.iloc[:, 36].values

# %%
#finally, let's divide the data into training and testing sets:
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Training the Algorithm
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=20, random_state=0)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)

# %%
#Evaluating the Algorithm
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.047323742752716016
# Mean Squared Error: 0.008438476631553886
# Root Mean Squared Error: 0.09186118130937511
